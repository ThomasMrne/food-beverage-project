# %% [markdown]
# # Customer Segmentation
#
# ## Objectif
# Ce notebook illustre comment le data product `ANALYTICS.CLIENTS_ENRICHIS` peut être utilisé pour réaliser une segmentation client.
#
# L’objectif est d’identifier des groupes homogènes de clients selon leurs caractéristiques démographiques et socio-économiques, afin d’adapter les stratégies marketing et commerciales. Aucun entraînement de modèle n’est réalisé dans le cadre de ce projet

# %% [markdown]
# ## Features utilisées
#
# Les variables issues du data product incluent :
#
# - Âge du client
# - Segment d’âge
# - Segment de revenu
# - Région
# - Pays
# - Genre
#
# Ces variables constituent une base adaptée à des méthodes de clustering.

# %%
SELECT
  customer_id,
  age,
  age_segment,
  income_segment,
  region,
  country,
  gender
FROM ANYCOMPANY_LAB.ANALYTICS.CLIENTS_ENRICHIS;
